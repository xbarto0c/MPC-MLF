# %% [markdown]
# <a href="https://colab.research.google.com/github/xbarto0c/MPC-MLF/blob/main/Lab_05_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]];
y = [0, 1, 1, 0];

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential(); # data projdou v řadě
model.add(Dense(6, input_dim=2, activation='sigmoid')); # přidání skryté vrstvy, dva neurony a dva vstupní neurony
model.add(Dense(1, activation='sigmoid')); # přidání jednoho výstupního neuronu

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.9); # stochastický gradientní pokles, hyperparametr learning_rate
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy']);

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs = 500, batch_size = 1, verbose = 1); # 2000 iterací batch_size -> po kolika vzorcích se trénuje model - střední hodnota a chyba + zpětná propagace
# Out:
# 4/4 [==============================] - 8s 14ms/step - loss: 1.3199 - accuracy: 0.0000e+00
# Epoch 2/500
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1472 - accuracy: 0.0000e+00
# Epoch 3/500
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0325 - accuracy: 0.2500
# Epoch 4/500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0225 - accuracy: 0.2500
# Epoch 5/500
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9903 - accuracy: 0.2500
# Epoch 6/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8839 - accuracy: 0.5000
# Epoch 7/500
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8373 - accuracy: 0.5000
# Epoch 8/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9659 - accuracy: 0.2500
# Epoch 9/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9247 - accuracy: 0.2500
# Epoch 10/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9030 - accuracy: 0.5000
# Epoch 11/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8256 - accuracy: 0.2500
# Epoch 12/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9102 - accuracy: 0.2500
# Epoch 13/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8308 - accuracy: 0.5000
# Epoch 14/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9142 - accuracy: 0.2500
# Epoch 15/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8076 - accuracy: 0.5000
# Epoch 16/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8402 - accuracy: 0.5000
# Epoch 17/500
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8758 - accuracy: 0.2500
# Epoch 18/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8637 - accuracy: 0.2500
# Epoch 19/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7947 - accuracy: 0.5000
# Epoch 20/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7843 - accuracy: 0.5000
# Epoch 21/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8444 - accuracy: 0.5000
# Epoch 22/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8323 - accuracy: 0.5000
# Epoch 23/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8282 - accuracy: 0.5000
# Epoch 24/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8343 - accuracy: 0.2500
# Epoch 25/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8238 - accuracy: 0.5000
# Epoch 26/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7809 - accuracy: 0.5000
# Epoch 27/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7674 - accuracy: 0.5000
# Epoch 28/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8223 - accuracy: 0.2500
# Epoch 29/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8040 - accuracy: 0.5000
# Epoch 30/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8007 - accuracy: 0.5000
# Epoch 31/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7926 - accuracy: 0.2500
# Epoch 32/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7862 - accuracy: 0.5000
# Epoch 33/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7882 - accuracy: 0.2500
# Epoch 34/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7864 - accuracy: 0.2500
# Epoch 35/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7262 - accuracy: 0.2500
# Epoch 36/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7757 - accuracy: 0.2500
# Epoch 37/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7555 - accuracy: 0.5000
# Epoch 38/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7248 - accuracy: 0.5000
# Epoch 39/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7559 - accuracy: 0.7500
# Epoch 40/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7088 - accuracy: 0.5000
# Epoch 41/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6994 - accuracy: 0.7500
# Epoch 42/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5000
# Epoch 43/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6874 - accuracy: 0.7500
# Epoch 44/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7236 - accuracy: 0.5000
# Epoch 45/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7107 - accuracy: 0.2500
# Epoch 46/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7031 - accuracy: 0.7500
# Epoch 47/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6995 - accuracy: 0.5000
# Epoch 48/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6555 - accuracy: 0.7500
# Epoch 49/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6715 - accuracy: 0.5000
# Epoch 50/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.5000
# Epoch 51/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.2500
# Epoch 52/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.7500
# Epoch 53/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.2500
# Epoch 54/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6471 - accuracy: 0.7500
# Epoch 55/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6438 - accuracy: 0.7500
# Epoch 56/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6209 - accuracy: 0.5000
# Epoch 57/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6361 - accuracy: 0.7500
# Epoch 58/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6376 - accuracy: 0.7500
# Epoch 59/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6244 - accuracy: 0.5000
# Epoch 60/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6253 - accuracy: 0.7500
# Epoch 61/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6173 - accuracy: 0.7500
# Epoch 62/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5898 - accuracy: 0.7500
# Epoch 63/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6085 - accuracy: 0.5000
# Epoch 64/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6011 - accuracy: 0.7500
# Epoch 65/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6118 - accuracy: 0.7500
# Epoch 66/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.5000
# Epoch 67/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5931 - accuracy: 0.7500
# Epoch 68/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5817 - accuracy: 0.7500
# Epoch 69/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5991 - accuracy: 0.7500
# Epoch 70/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5732 - accuracy: 0.5000
# Epoch 71/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5780 - accuracy: 0.7500
# Epoch 72/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5768 - accuracy: 0.7500
# Epoch 73/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5683 - accuracy: 0.7500
# Epoch 74/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5673 - accuracy: 0.5000
# Epoch 75/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5667 - accuracy: 0.7500
# Epoch 76/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5622 - accuracy: 0.5000
# Epoch 77/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5416 - accuracy: 0.7500
# Epoch 78/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5512 - accuracy: 0.7500
# Epoch 79/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5726 - accuracy: 0.7500
# Epoch 80/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5470 - accuracy: 0.7500
# Epoch 81/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5409 - accuracy: 0.5000
# Epoch 82/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5504 - accuracy: 0.7500
# Epoch 83/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5281 - accuracy: 0.7500
# Epoch 84/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5420 - accuracy: 0.7500
# Epoch 85/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5302 - accuracy: 0.7500
# Epoch 86/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5181 - accuracy: 0.7500
# Epoch 87/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.7500
# Epoch 88/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.7500
# Epoch 89/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.7500
# Epoch 90/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4830 - accuracy: 0.7500
# Epoch 91/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4816 - accuracy: 0.7500
# Epoch 92/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4941 - accuracy: 0.7500
# Epoch 93/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4895 - accuracy: 0.7500
# Epoch 94/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4566 - accuracy: 0.7500
# Epoch 95/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4539 - accuracy: 1.0000
# Epoch 96/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4527 - accuracy: 0.7500
# Epoch 97/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4414 - accuracy: 0.7500
# Epoch 98/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.7500
# Epoch 99/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.7500
# Epoch 100/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4246 - accuracy: 0.7500
# Epoch 101/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4059 - accuracy: 0.7500
# Epoch 102/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.7500
# Epoch 103/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3888 - accuracy: 0.7500
# Epoch 104/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3682 - accuracy: 0.7500
# Epoch 105/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.7500
# Epoch 106/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3436 - accuracy: 1.0000
# Epoch 107/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3449 - accuracy: 1.0000
# Epoch 108/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3247 - accuracy: 1.0000
# Epoch 109/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3156 - accuracy: 0.7500
# Epoch 110/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3109 - accuracy: 1.0000
# Epoch 111/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2834 - accuracy: 1.0000
# Epoch 112/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2873 - accuracy: 1.0000
# Epoch 113/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2763 - accuracy: 1.0000
# Epoch 114/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 1.0000
# Epoch 115/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2583 - accuracy: 1.0000
# Epoch 116/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2377 - accuracy: 1.0000
# Epoch 117/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2329 - accuracy: 1.0000
# Epoch 118/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2274 - accuracy: 1.0000
# Epoch 119/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2137 - accuracy: 1.0000
# Epoch 120/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2088 - accuracy: 1.0000
# Epoch 121/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 1.0000
# Epoch 122/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1985 - accuracy: 1.0000
# Epoch 123/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1861 - accuracy: 1.0000
# Epoch 124/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 1.0000
# Epoch 125/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1778 - accuracy: 1.0000
# Epoch 126/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1687 - accuracy: 1.0000
# Epoch 127/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 1.0000
# Epoch 128/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1590 - accuracy: 1.0000
# Epoch 129/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1518 - accuracy: 1.0000
# Epoch 130/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 1.0000
# Epoch 131/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1425 - accuracy: 1.0000
# Epoch 132/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1369 - accuracy: 1.0000
# Epoch 133/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 1.0000
# Epoch 134/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1312 - accuracy: 1.0000
# Epoch 135/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1268 - accuracy: 1.0000
# Epoch 136/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1222 - accuracy: 1.0000
# Epoch 137/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1196 - accuracy: 1.0000
# Epoch 138/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1163 - accuracy: 1.0000
# Epoch 139/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1127 - accuracy: 1.0000
# Epoch 140/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1087 - accuracy: 1.0000
# Epoch 141/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1060 - accuracy: 1.0000
# Epoch 142/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 1.0000
# Epoch 143/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1009 - accuracy: 1.0000
# Epoch 144/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 1.0000
# Epoch 145/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 1.0000
# Epoch 146/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0935 - accuracy: 1.0000
# Epoch 147/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 1.0000
# Epoch 148/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 1.0000
# Epoch 149/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 1.0000
# Epoch 150/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 151/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 1.0000
# Epoch 152/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0809 - accuracy: 1.0000
# Epoch 153/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 1.0000
# Epoch 154/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0769 - accuracy: 1.0000
# Epoch 155/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0756 - accuracy: 1.0000
# Epoch 156/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 157/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 1.0000
# Epoch 158/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 159/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 1.0000
# Epoch 160/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 1.0000
# Epoch 161/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 162/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 163/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 164/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 165/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 166/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 167/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 168/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 169/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 170/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 171/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 172/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 173/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 174/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 175/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 176/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 177/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 178/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 179/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 180/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 181/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 182/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 183/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 184/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 185/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 186/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 187/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 188/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 189/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 190/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 191/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 192/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 193/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 194/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 195/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 196/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 197/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 198/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 199/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 200/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 201/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 202/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 203/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 204/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 205/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 206/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 207/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 208/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 209/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 210/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 211/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 212/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 213/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 214/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 215/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 216/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 217/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 218/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 219/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 220/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 221/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 222/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 223/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 224/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 225/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 226/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 227/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 228/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 229/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 230/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 231/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 232/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 233/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 234/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 235/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 236/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 237/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 238/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 239/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 240/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 241/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 242/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 243/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 244/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 245/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 246/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 247/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 248/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 249/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 250/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 251/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 252/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 253/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 254/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 255/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 256/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 257/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 258/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 259/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 260/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 261/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 262/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 263/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 264/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 265/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 266/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 267/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 268/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 269/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 270/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 271/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 272/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 273/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 274/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 275/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 276/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 277/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 278/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 279/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 280/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 281/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 282/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 283/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 284/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 285/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 286/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 287/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 288/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 289/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 290/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 291/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 292/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 293/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 294/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 295/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 296/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 297/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 298/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 299/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 300/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 301/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 302/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 303/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 304/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 305/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 306/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 307/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 308/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 309/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 310/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 311/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 312/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 313/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 314/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 315/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 316/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 317/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 318/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 319/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 320/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 321/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 322/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 323/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 324/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 325/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 326/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 327/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 328/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 329/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 330/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 331/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 332/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 333/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 334/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 335/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 336/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 337/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 338/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 339/500
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 340/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 341/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 342/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 343/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 344/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 345/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 346/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 347/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 348/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 349/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 350/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 351/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 352/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 353/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 354/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 355/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 356/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 357/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 358/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 359/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 360/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 361/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 362/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 363/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 364/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 365/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 366/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 367/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 368/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 369/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 370/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 371/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 372/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 373/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 374/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 375/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 376/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 377/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 378/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 379/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 380/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 381/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 382/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 383/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 384/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 385/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 386/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 387/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 388/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 389/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 390/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 391/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 392/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 393/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 394/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 395/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 396/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 397/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 398/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 399/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 400/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 401/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 402/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 403/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 404/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 405/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 406/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 407/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 408/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 409/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 410/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 411/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 412/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 413/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 414/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 415/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 416/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 417/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 418/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 419/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 420/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 421/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 422/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 423/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 424/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 425/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 426/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 427/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 428/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 429/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 430/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 431/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 432/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 433/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 434/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 435/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 436/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 437/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 438/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 439/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 440/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 441/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 442/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 443/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 444/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 445/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 446/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 447/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 448/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 449/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 450/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 451/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 452/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 453/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 454/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 455/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 456/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 457/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 458/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 459/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 460/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 461/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 462/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 463/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 464/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 465/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 466/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 467/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 468/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 469/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 470/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 471/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 472/500
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 473/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 474/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 475/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 476/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 477/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 478/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 479/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 480/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 481/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 482/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 483/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 484/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 485/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 486/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 487/500
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 488/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 489/500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 490/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 491/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 492/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 493/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 494/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 495/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 496/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 497/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 498/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 499/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 500/500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0);
print('Accuracy: {:.2f}'.format(accuracy*100));
# Out:
# Accuracy: 100.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  prediction = model.predict([data_sample]);
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}");
# Out:
# 1/1 [==============================] - 0s 78ms/step
# Data sample is [0, 0], prediction from model [[0.00151181]], ground_truth 0
# 1/1 [==============================] - 0s 41ms/step
# Data sample is [0, 1], prediction from model [[0.9948462]], ground_truth 1
# 1/1 [==============================] - 0s 34ms/step
# Data sample is [1, 0], prediction from model [[0.99323696]], ground_truth 1
# 1/1 [==============================] - 0s 37ms/step
# Data sample is [1, 1], prediction from model [[0.01361986]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure();
plt.plot(history.history['loss']);
plt.xlabel('n epochs');
plt.ylabel('loss');

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow.keras import models, layers, utils, backend as K
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
from google.colab import drive
drive.mount('/content/drive');
path_to_dataset = 'drive/MyDrive/MMLF/Lab_05/voting_complete.csv'; # change the PATH
pd_dataset = pd.read_csv(path_to_dataset);
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy();
    pd_dataset = pd_dataset[pd_dataset.columns[1:]];
    index = np.arange(len(pd_dataset));
    index = np.random.permutation(index);
    train_ammount = int(len(index)*test_ratio);
    train_ids = index[train_ammount:];
    test_ids = index[:train_ammount];
    
    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index();
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index();
    
    train_dataset = train_dataset[train_dataset.columns[1:]];
    test_dataset = test_dataset[test_dataset.columns[1:]];

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset);

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
# klasifikační problém - republikán/demokrat
# 16 vlastností
# binární data
# jsou
# 2 značky
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     ?                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 343                   y                          n
# 344                   n                          n
# 345                   n                          n
# 346                   n                          ?
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 343                                 y                    n               ?
# 344                                 y                    y               y
# 345                                 y                    n               n
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           n                       y
# 344                           y                       n
# 345                           n                       y
# 346                           y                       n
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         y          y           y
# 344                         n          y           y
# 345                         y          y           y
# 346                         n          n           n
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      n
# 344                            n                  y                      y
# 345                            n                  n                      n
# 346                            y                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     ?                 y                                      y
# 344     y                 n                                      y
# 345     n                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE
x = pd.get_dummies(x_train); # náhrada y a n za identifikátory

# %%
#WRITE YOUR CODE HERE
y_train = y_train.replace('republican', 1);
y = y_train.replace('democrat', 0); # demokrat = 0, republikán = 1

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model = Sequential() # data projdou v řadě
model.add(Dense(3, input_dim=len(x.axes[1]), activation='sigmoid')) # přidání skryté vrstvy
model.add(Dense(1, activation='sigmoid')) # přidání jednoho výstupního neuronu

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary();
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 3)                 147
#
#  dense_5 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5); # stochastický gradientní pokles, hyperparametr learning_rate
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy']);

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#WRITE YOUR CODE HERE
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.25, random_state= 8); # 0.25 x 0.8 = 0.2
history = model.fit(X_train, y_train, epochs = 100, batch_size = 1, verbose = 1); # 2000 iterací batch_size -> po kolika vzorcích se trénuje model - střední hodnota a chyba + zpětná propagace
# Out:
# Epoch 1/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.2578 - accuracy: 0.8966
# Epoch 2/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.1444 - accuracy: 0.9464
# Epoch 3/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.1200 - accuracy: 0.9617
# Epoch 4/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.1229 - accuracy: 0.9617
# Epoch 5/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0843 - accuracy: 0.9693
# Epoch 6/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.1084 - accuracy: 0.9617
# Epoch 7/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0938 - accuracy: 0.9617
# Epoch 8/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0679 - accuracy: 0.9655
# Epoch 9/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0598 - accuracy: 0.9847
# Epoch 10/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0747 - accuracy: 0.9693
# Epoch 11/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0505 - accuracy: 0.9885
# Epoch 12/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0484 - accuracy: 0.9808
# Epoch 13/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0370 - accuracy: 0.9847
# Epoch 14/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0561 - accuracy: 0.9770
# Epoch 15/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0397 - accuracy: 0.9885
# Epoch 16/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0580 - accuracy: 0.9732
# Epoch 17/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0300 - accuracy: 0.9885
# Epoch 18/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0448 - accuracy: 0.9847
# Epoch 19/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0234 - accuracy: 0.9885
# Epoch 20/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0298 - accuracy: 0.9923
# Epoch 21/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0484 - accuracy: 0.9847
# Epoch 22/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0314 - accuracy: 0.9885
# Epoch 23/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0654 - accuracy: 0.9693
# Epoch 24/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0339 - accuracy: 0.9847
# Epoch 25/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0315 - accuracy: 0.9885
# Epoch 26/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0220 - accuracy: 0.9923
# Epoch 27/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0367 - accuracy: 0.9847
# Epoch 28/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0416 - accuracy: 0.9885
# Epoch 29/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0270 - accuracy: 0.9923
# Epoch 30/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 31/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0142 - accuracy: 0.9962
# Epoch 32/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 33/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 34/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 35/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9923
# Epoch 36/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 37/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 38/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 39/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 40/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 41/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 42/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 43/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 44/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 45/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 46/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 47/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 48/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 49/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 50/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 51/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 52/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 53/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 54/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 55/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 56/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 57/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 58/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 59/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 60/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 61/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 62/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 63/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 64/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 65/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 66/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 67/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 68/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 69/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 70/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 71/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 72/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 73/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 74/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 75/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 76/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 77/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 78/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 79/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 80/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 81/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 82/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 83/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 84/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 85/100
# 261/261 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 86/100
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 87/100
# 261/261 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 88/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.9740e-04 - accuracy: 1.0000
# Epoch 89/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.8597e-04 - accuracy: 1.0000
# Epoch 90/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.7476e-04 - accuracy: 1.0000
# Epoch 91/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.6351e-04 - accuracy: 1.0000
# Epoch 92/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.5275e-04 - accuracy: 1.0000
# Epoch 93/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.4149e-04 - accuracy: 1.0000
# Epoch 94/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.3268e-04 - accuracy: 1.0000
# Epoch 95/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.2167e-04 - accuracy: 1.0000
# Epoch 96/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.1101e-04 - accuracy: 1.0000
# Epoch 97/100
# 261/261 [==============================] - 1s 2ms/step - loss: 9.0138e-04 - accuracy: 1.0000
# Epoch 98/100
# 261/261 [==============================] - 1s 2ms/step - loss: 8.9421e-04 - accuracy: 1.0000
# Epoch 99/100
# 261/261 [==============================] - 1s 2ms/step - loss: 8.8503e-04 - accuracy: 1.0000
# Epoch 100/100
# 261/261 [==============================] - 1s 2ms/step - loss: 8.7528e-04 - accuracy: 1.0000

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
x = pd.get_dummies(x_test)
y_test = y_test.replace('republican', 1);
y = y_test.replace('democrat', 0);

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model.evaluate(x, y, verbose=0);
print('Accuracy: {:.2f} %'.format(accuracy*100));
print('Loss: {:.2f} %'.format(loss*100));

val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0);
print('Validation accuracy: {:.2f} %'.format(val_accuracy*100));
print('Validation loss: {:.2f} %'.format(val_loss*100));
# Out:
# Accuracy: 93.10 %
# Loss: 44.04 %
# Validation accuracy: 96.55 %
# Validation loss: 11.82 %

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
plt.figure();
plt.plot(history.history['loss']);
plt.xlabel('n epochs');
plt.ylabel('loss');

plt.figure();
plt.plot(history.history['accuracy']);
plt.xlabel('n epochs');
plt.ylabel('accuracy');
